# %%
from matcher.graph import compile_matcher_graph

graph = compile_matcher_graph()
res = await graph.invoke({"analysisId": "123"})
# Out:
# /Users/aberman/Documents/Workshop/repio-intelligence/src/matcher/nodes/enrichment/language.py:19: LangChainBetaWarning: The function `init_chat_model` is in beta. It is actively being worked on, so the API may change.
#   model = init_chat_model(
# test node
# {'criterion_id': None, 'criterion_description': 'Minimum of 1 year of experience in a Consumer startup that raised more than $100k in funding.', 'criterion_context': "Given Ynstant's startup nature and focus on real-time carpooling, experience in a Consumer startup that raised more than $100k in funding is crucial. This criteria should be strictly followed"}
# Experience in the mobility sector, especially in a startup, provides valuable insights into the challenges and opportunities of developing innovative transportation solutions like Ynstant's carpooling app.
# Automation skills are valuable for reducing manual workload and increasing efficiency in handling CEE files, aligning with Ynstant's innovative approach to operations.
# Given Ynstant's startup nature and focus on real-time carpooling, experience in a Consumer startup that raised more than $100k in funding is crucial. This criteria should be strictly followed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from matcher.graph import compile_matcher_graph
#       3 graph = compile_matcher_graph()
# ----> 4 res = await graph.invoke({"analysisId": "123"})
#
# TypeError: object AddableValuesDict can't be used in 'await' expression

# %%
res

# %%
import pprint
pprint.pprint(res, indent=2, width=10)

# %%
from IPython.display import Image, display
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
from scorecard.graph import create_scorecard_graph


scorecard_graph = create_scorecard_graph()
from IPython.display import Image, display
display(Image(scorecard_graph.get_graph(xray=True).draw_mermaid_png()))
