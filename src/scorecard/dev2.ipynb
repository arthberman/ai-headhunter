# %%
# Read raw_job_posting.txt
with open("raw_job_posting.txt", "r") as f:
    raw_job_posting = f.read()

# %%
from scorecard.sub_graph.enrichment.graph import get_enrichment_graph
from scorecard.nodes.node_generate_questions import node_generate_questions
from langgraph.graph import END, START, StateGraph
from scorecard.state import ScorecardGraphState

from scorecard.state import ScorecardInputGraphState

# Define a new graph
workflow = StateGraph(ScorecardGraphState, input=ScorecardInputGraphState)
workflow.add_node("agent_enrichment", get_enrichment_graph())
workflow.add_node("generate_questions", node_generate_questions)
workflow.add_edge(START, "agent_enrichment")
workflow.add_edge("agent_enrichment", "generate_questions")
workflow.add_edge("generate_questions", END)
graph = workflow.compile()


res = graph.invoke({"raw_job_posting": raw_job_posting})
print(res)
# Out:
# /Users/aberman/Documents/Workshop/repio-intelligence/.venv/lib/python3.12/site-packages/langsmith/client.py:5301: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   prompt = loads(json.dumps(prompt_object.manifest))
# /Users/aberman/Documents/Workshop/repio-intelligence/src/scorecard/nodes/node_generate_questions.py:14: LangChainBetaWarning: The function `init_chat_model` is in beta. It is actively being worked on, so the API may change.
#   model = init_chat_model(
# {'raw_job_posting': "Ynstant\nOperations Manager CDI Paris Salaire :52K à 72K\xa0€ Début :19 août 2024 Télétravail occasionnel Expérience :> 2 ans Compétences & expertises Compétences en communication Outils d'automatisation Sensibilité culturelle Pandas Sql\nentreprise : Ynstant\n\nYnstant est une startup qui révolutionne la mobilité du quotidien pour la rendre plus durable, grâce à une application de covoiturage instantané. Concrètement, Ynstant permet aux conducteurs de covoiturer en deux clics, sans détour et au dernier moment avant de partir, préservant ainsi leur flexibilité.\n\nDescriptif du poste\nMission\xa0: Le Ops Manager sera responsable de la gestion des opérations quotidiennes des Certificats d’Economie d’Energie (CEE) en s’appuyant sur de la data. Les missions sont :\n-Monitoring des dossiers CEE et optimisation de chaque étape du parcours\n-Traitement des dossiers présentant des anomalies\n-Conformité des dossiers CEE à la réglementation\nProfil recherché\nCOMPÉTENCES TECHNIQUES\n- Extrême rigueur (presque comptable)\n- Compétences en data : capable de faire de l’analyse de données (SQL, Python, pandas, etc.)\nBONUS : Mise en place d’outils d’automatisation / scripts pour éviter de traiter manuellement les dossiers présentant des anomalies\nCOMPÉTENCES COMPORTEMENTALES\n- Curiosité et proactivité : aller chercher l’information auprès des différents acteurs pour comprendre les processus, les problèmes, et la réglementation. Prendre des initiatives pour résoudre les anomalies.\n- Niaque / esprit de compétition / aime le challenge\n- Résistance à la pression : enjeux conséquents, charge mentale\nCOMPÉTENCES CULTURELLES\n- Etre orienté résultats (Get shit done++)\n- Honnêteté intellectuelle\n- Humilité\n- Autonomie\n- Exigence envers soi-même et les autres\n- Ténacité\nDéroulement des entretiens\nLe process de recrutement se déroule en 4 étapes :\n- Un first call\n- Un cas pratique & une mise en situation dans nos locaux (Paris)\n- Un entretien de fit culturel dans nos locaux\n- 3-5 ref calls\nFIRST CALL\nObjectif :\xa0Ce premier entretien téléphonique est une opportunité pour nous de mieux comprendre votre parcours, vos compétences et vos motivations pour le poste de Ops Manager. C’est également l’occasion pour vous de poser des questions sur l’entreprise, le rôle et les attentes.\nDurée :\xa030 minutes\nCAS PRATIQUE & MISE EN SITUATION\nObjectif :\xa0Évaluer vos compétences techniques et votre capacité à résoudre des problèmes concrets. Ce cas pratique vous permettra de démontrer votre rigueur, votre esprit analytique et votre capacité à travailler avec des données.\nDurée :\xa01h30 (1 heure pour le travail sur le cas pratique et 30min pour la présentation et la discussion)\nENTRETIEN FIT CULTUREL\nObjectif :\xa0Évaluer l’adéquation de votre personnalité et de vos valeurs avec la culture de notre entreprise. Cet entretien vise à s’assurer que vous partagez nos principes et que vous vous épanouirez au sein de notre équipe.\nDurée :\xa045 minutes", 'global_context': ['Ynstant is a startup focused on providing real-time carpooling services within the ridesharing industry, allowing drivers to carpool instantly with minimal effort. Founded in 2022, it targets urban commuters looking for flexible and cost-effective transportation options.', 'Ynstant has not raised any funding rounds yet and operates independently without institutional or angel investors. It is a small startup with a competitive landscape that includes companies like BluSmart and Karos.', 'The company culture at Ynstant emphasizes results orientation, intellectual honesty, humility, autonomy, and tenacity. Employees are expected to be proactive, curious, and resilient under pressure, fostering a challenging yet supportive work environment.'], 'questions': ListQuestions(questions=[Question(question='What level of proficiency in SQL and Python is expected for this role?', criteria_type=<CriteriaType.HARD_SKILL: 'HARD_SKILL'>), Question(question='Are there ...

# %%
from pprint import pprint

# new line at every question
for question in res["questions"]:
    print("\n")
    pprint(question, indent=2)
# Out:
# ( 'questions',
#   [ Question(question='What level of proficiency in SQL and Python is expected for this role?', criteria_type=<CriteriaType.HARD_SKILL: 'HARD_SKILL'>),
#     Question(question='Are there specific types of data analysis or projects that the candidate should have experience with?', criteria_type=<CriteriaType.HARD_SKILL: 'HARD_SKILL'>),
#     Question(question='What specific automation tools or scripting languages are preferred for this role?', criteria_type=<CriteriaType.HARD_SKILL: 'HARD_SKILL'>),
#     Question(question='Could you elaborate on the types of cultural sensitivity that are important for this position?', criteria_type=<CriteriaType.SOFT_SKILL: 'SOFT_SKILL'>),
#     Question(question='What specific challenges or pressures should the candidate be prepared to handle in this role?', criteria_type=<CriteriaType.SOFT_SKILL: 'SOFT_SKILL'>),
#     Question(question="How does the company define 'intellectual honesty' in the context of its culture?", criteria_type=<CriteriaType.SOFT_SKILL: 'SOFT_SKILL'>),
#     Question(question='What specific industry knowledge related to energy certificates or sustainability is beneficial for this role?', criteria_type=<CriteriaType.INDUSTRY_KNOWLEDGE: 'INDUSTRY_KNOWLEDGE'>)])
